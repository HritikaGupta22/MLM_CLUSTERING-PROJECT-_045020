# %% [markdown]
# #REPORT

# %% [markdown]
# #**Unveiling Patterns: A Clustering Analysis of Earthquake Data**

# %% [markdown]
# #1. OBJECTIVES :
# > Objective 1: Identification of Seismic Activity Patterns or earthquake patterns using Unsupervised Machine learning Clustering Algorithms.
#
# > Objective 2: Identification of Appropriate Number of seismic Activity Patterns or earthquake patterns or Clusters.
#
# > Objective 3: Determination of Seismic Activity Patterns or Cluster Characteristic.

# %% [markdown]
# # 2. Data Description:
# > 2.1 Data Source, Size, Shape:
# >> 2.1.1 Data Source:
# >>>Kaggle -> Significant Earthquakes, 1900-Present
#
# >>>https://www.kaggle.com/datasets/usamabuttar/significant-earthquakes
#
# >> 2.1.2 Data Size:
# >>>  => 17746 KB or 17.3 MB
# >> 2.1.3 Data Shape:
# >>> Size: The dataset contains 100,989 rows or data points and 22 columns or variables.
# >>> Shape: The shape of the dataset is (100989, 22), suggesting that there are 100,989 rows and 22 columns.
#
# > 2.2 Description of Variables
# >> 2.2.1. Index Variable: index
#
# >> 2.2.2 Categorical Variables : magType, net, type, status, locationSource, magSource
#
# >>> 2.2.2.1 Nominal Variables : magType, net, type, status, locationSource, magSource
#
# >>> 2.2.2.2 Ordinal Variables : None identified in this dataset.
#
# >> 2.2.3. Non-Categorical Variables: time, latitude, longitude, depth, mag, nst, gap, dmin, rms, id, updated, place, horizontalError, depthError, magError, magNst.
#
# >2.3. Descriptive Statistics
# >> 2.3.1 Descriptive Statistics: Categorical Variables or Features
# >>>
# We have calculated the count and percentage of all mentioned categorical features below.
# Removing the 'net', 'type', 'status', and 'locationSource' columns from the dataset because the majority of occurrences are concentrated within one or two specific categories.
# >>2.3.2. Descriptive Statistics: Non-Categorical Variables or Features:
# >>> 2.3.2.1. Measures of Central Tendency: mentioned below
#
# >>>2.3.2.2. Measures of Dispersion:
# >>>>
# 1. Standard deviation of'latitude': 30.04
# 2. Standard deviation of'longitude': 121.78
# 3. Standard deviation of'depth': 108.52
# 4. Standard deviation of'mag': 0.48
# 5. Standard deviation of'nst': 127.02
# 6. Standard deviation of'gap': 38.48
# 7. Standard deviation of'dmin': 5.16
# 8. Standard deviation of'rms': 0.38
# 9. Standard deviation of'horizontalError': 4.4
# 10. Standard deviation of'depthError': 10.81
# 11. Standard deviation of'magError': 0.16
# 12. Standard deviation of'magNst': 80.14
#
# >>>2.3.2.3. Correlation Statistics (with Test of Correlation): correlation chart among variable drawn below

# %% [markdown]
# # 3. Analysis of Data
# > 3.1. Data Pre-Processing
# >> 3.1.1 About Missing Data
# >>> 3.1.1.1 Missing Data Statistics and Treatment (Records)
# >>>> 3.1.1.1.1 Missing Data Statistics: Records
# >>>>> Maximum no. of columns missing in a records are 9.
#
# >>>> 3.1.1.1.2 Missing Data Treatment: Records
# >>>>>  Removal of Records with More Than 50% Missing Data: None
#
# >>> 3.1.1.2 Missing Data Statistics and Treatment (Categorical Variables)
# >>>>3.1.1.2.1 Missing Data Statistics : None
#
# >>>> 3.1.1.2.2 Missing Data Treatment:
# >>>>> Removal of Variables or Features with More Than 50% Missing Data: None
#
# >>> 3.1.1.3 Missing Data Statistics and Treatment (Non-Categorical Variables)
# >>>> 3.1.1.3.1 Missing Data Statistics:
# >>>>>>
#        1. Variable depth: 285 missing values
#        2. Variable nst: 70,600 missing values
#        3. Variable gap: 60,307 missing values
#        4. Variable dmin: 80,251 missing values
#        5. Variable rms: 28,745 missing values
#        6. Variable place: 889 missing values
#        7. Variable horizontalError: 81,626 missing values
#        8. Variable depthError: 49,713 missing values
#        9. Variable magError: 66,997 missing values
#        10. Variable magNst: 59,981 missing values
#
# >>>> 3.1.1.3.2 Missing Data Treatment:
#
# >>>>> 3.1.1.3.2.1 Removal of Variables or Features with more Than 50% Missing Data (50% of 100989 = 50495) :
#
# >>>>>> AS nst, gap, dmin, horizontalError,magError,magNst are havaing more than 50% records are missing.
# We will remove place as well because it is the naming variable.
#
# >>>>> 3.1.1.3.2.2Imputation of Missing Data using Descriptive Statistics: Mean | Median
# >>>>>> When imputing depth, rms, depthError : Median ( because of the presence of outliers)

# %% [markdown]
# >> 3.1.2. Numerical Encoding of Categorical Variables or Features :
# >>>
# 1. We apply ordinal encoding to transform them into numerical representations.
# 2. Ordinal Encoding: Ordinal encoding assigns a unique numerical label to each
#    category within a categorical variable.
#
# >> 3.1.3. Outlier Statistics and Treatment (Scaling | Transformation)
# >>> 3.1.3.1. Outlier Statistics (Non-Categorical Variables):
# >>>> mag, depth, rms, depthError
#
# >>> 3.1.3.2 Outlier Treatment: Non-Categorical Variables or Features:
#
# >>> 3.1.3.3 Normalization using Min-Max Scaler: mag, depth, rms, depthError
#
# >> 3.1.4. Data Bifurcation: Training & Testing Sets
# >>>
# 1. The dataset is partitioned into two subsets: training and testing datasets.
# 2. Training dataset is 75% of complete data
# 3. Testing dataset is 25% of complete data

# %% [markdown]
# > **3.2. Data Analysis**
# >> 3.2.1 Metrics Used
# >>>3.2.1.1 Unsupervised Machine Learning Clustering Algorithm: **K-Means** (Base Model) | Metrics Used - Euclidean Distance
#
# >>>3.2.1.2. PO1 | PS1:: Unsupervised Machine Learning Clustering Algorithms: **BIRCH** | Metrics Used - Euclidean Distance
#
# >> 3.2.2 Performance Evaluation:
# >>> 3.2.2.1 for k-means
# >>>> 3.2.2.1.1 Clustering Model Performance Evaluation: Silhouette Score | Davies-Bouldin Score (Base Model: K-Mean)
# >>>>>>
# ![image.png](data:image/png;base64,...)
# >>>>>
# 1. The closer the sscore is to 1 and the dbscore is to 0, the better.
# 2. Among the cluster sizes evaluated, size 2 exhibits the most favorable sscore and dbscore, indicating well-defined clusters and strong cluster cohesion.
# 3. Following closely, cluster size 3 also demonstrates favorable performance, with a relatively low Davies-Bouldin score of 0.51.
# 3. This suggests effective clustering with minimal intra-cluster variability and significant inter-cluster variability.
# 4. Given the trivial nature of cluster size 2, **cluster size 3 emerges as a strong alternative.**
#
# >>>>3.2.2.1.2 Clustering Model Performance Evaluation: Time Statistics | Memory Statistics (Base Model: K-Mean) :
# >>>>>
# Time Taken : 601.8391733169556
# >>>>>
# Memory usage : 0.8515625 MB
#
# >>> 3.2.2.1 for BIRCH
# >>>>3.2.2.2.1 Clustering Model Performance Evaluation: Silhouette Score | Davies-Bouldin Score (Comparison Models: BIRCH)
# >>>>>>
# ![image.png](data:image/png;base64,...)
# >>>>>
# **Apart from k=2 ,At k=3, we are getting best sscore and dbscore because of triviality. we will choose k=3.**
#
# >>>> 3.2.2.2.2 Clustering Model Performance Evaluation: Time Statistics | Memory Statistics (Comparison Models: BIRCH) :
# >>>>>
#  Time Taken  : 405.3320965766907
# >>>>>
#  Memory usage : 55.109375 MB

# %% [markdown]
# >> 3.2.3 Cluster Analysis for Categorical varaiable(according to k-means)
# >>>>
# 3.2.3.1 For magType:
# >>>>
# **Null Hypothesis :** The null hypothesis states that there is no relationship among the clusers of magType.
# >>>>
# **Alternative Hypothesis (H1):** There is a relationship among the clusters of 'magType_y'.
# >>>>>
# The p-value( 2.5e-06) > than significance level(0.05).
# It indicates that we fail to reject the null hypothesis.
# >>>>
# There is insufficient evidence to conclude that there is no significant relationship among the clusters of 'magType'.
# >>>>
# 3.2.3.2 For net:
# >>>>
# **Null Hypothesis (H0):** There is no relationship among the clusters of net.
# >>>>
# **Alternative Hypothesis (H1):** There is a relationship among the clusters of net.
# >>>>>
# The p-value (1.08e-08) is very very small than the significance level (0.05), suggesting that we reject the null hypothesis.
# >>>>
# Therefore, there is insufficient evidence to conclude that there is no significant relationship among the clusters of net.
#
# >>>>
# 3.2.3.3 For type:
# >>>>
# **Null Hypothesis (H0):** There is no relationship among the clusters of type.
# >>>>
# **Alternative Hypothesis (H1):** There is a relationship among the clusters of type.
# >>>>>
# The p-value (0.79) is greater than the significance level (0.05), suggesting that we fail to reject the null hypothesis.
# >>>>
# Therefore, there is insufficient evidence to conclude that there is a significant relationship among the clusters of type.
# >>>>
# 3.2.3.4 For status:
# >>>>
# **Null Hypothesis (H0):** There is no relationship among the clusters of sttatus.
# >>>>
# **Alternative Hypothesis (H1):** There is a relationship among the clusters of status.
# >>>>>
# The p-value (0.5) is greater than the significance level (0.05), suggesting that we fail to reject the null hypothesis.
# >>>>
# Therefore, there is insufficient evidence to conclude that there is a significant relationship among the clusters of status.
# >>>>
# 3.2.3.5 For locationSource:
# >>>>
# **Null Hypothesis (H0):** There is no relationship among the clusters of locationSource.
# >>>>
# **Alternative Hypothesis (H1):** There is a relationship among the clusters of locationSource.
# >>>>>
# The p-value (2.6e-07) is very small than the significance level (0.05), suggesting that we fail to reject the null hypothesis.
# >>>>
# Therefore, there is insufficient evidence to conclude that there is no significant relationship among the clusters of locationSource.
# >>>>
# 3.2.3.6 For magSource:
# >>>>
# **Null Hypothesis (H0):** There is no relationship among the clusters of 'magSource_y'.
# >>>>
# **Alternative Hypothesis (H1):** There is a relationship among the clusters of 'magSource_y'.
# >>>>>
# The p-value (2.7e-07) is smaller than the significance level (0.05), suggesting that we fail to reject the null hypothesis.
# >>>>
# Therefore, there is insufficient evidence to conclude that there is no significant relationship among the clusters of magSource.

# %% [markdown]
# >>3.2.4 Cluster Analysis of non - categorical  variable.
# >>>>3.2.4.1 For latitude:
#
# >>>>**Null Hypothesis (H0):** There is no significant difference in the mean latitude among clusters 0, 1, and 2.
#
# >>>>**Alternate Hypothesis (H1):** There is a significant difference in the mean latitude among at least two of the clusters (0, 1, and 2).
# >>>>>p-value < 0.05, It is conclude that at least one of the mean latitude among clusters 0,1 and 2 is significantly different.
#
# >>>> **Tukey's  (HSD) test**
# 1. The difference in mean latitude between cluster 0 and cluster 1 is statistically significant (p-value < 0.05)
# 2. The difference in mean latitude between cluster 1 and cluster 2 is also statistically significant (p-value < 0.05)
# 3. The difference in mean latitude between cluster 0 and cluster 2 is also statistically significant (p-value < 0.05)
#
#
# >>>>3.2.4.2 For longitude:
#
# >>>>**Null Hypothesis (H0):** There is no significant difference in the mean longitude among clusters 0, 1, and 2.
#
# >>>>**Alternate Hypothesis (H1):** There is a significant difference in the mean longitude among at least two of the clusters (0, 1, and 2).
# >>>>> p-value < 0.05, It is conclude that at least one of the mean latitude among clusters 0,1 and 2 is significantly different.
# >>>>**Tukey's  (HSD) test**
# 1. The difference in mean longitude between cluster 0 and cluster 1 is statistically significant (p-value < 0.05)
# 2. The difference in mean longitude between cluster 1 and cluster 2 is also statistically significant (p-value < 0.05)
# 3. The difference in mean longitude between cluster 0 and cluster 2 is also statistically significant (p-value < 0.05)
#
# >>>>3.2.4.3 For magnitude
#
# >>>>**Null Hypothesis (H0):** There is no significant difference in the mean magnitude among clusters 0, 1, and 2.
#
# >>>>**Alternate Hypothesis (H1):** There is a significant difference in the mean magnitude among at least two of the clusters (0, 1, and 2).
# >>>>> p-value < 0.05, It is conclude that at least one of the mean magnitude among clusters 0,1 and 2 is significantly different.
#
# >>>>**Tukey's  (HSD) test**
# 1. The difference in mean magnitude between cluster 0 and cluster 1 is statistically significant (p-value < 0.05)
# 2. The difference in mean magnitude between cluster 1 and cluster 2 is also statistically significant (p-value < 0.05)
# 3. The difference in mean magnitude between cluster 0 and cluster 2 is also statistically significant (p-value < 0.05)
#
#
# >>>>3.2.4.4 For depth
#
# >>>>**Null Hypothesis (H0):** There is a significant difference in the mean depth among at least two of the clusters (0, 1, and 2).
#
# >>>>**Alternate Hypothesis (H1):**  There is a significant difference in the mean depth among at least two of the clusters (0, 1, and 2).
#
# >>>>>p-value < 0.05, It is conclude that at least one of the mean depth among clusters 0,1 and 2 is significantly different.
#
# >>>>**Tukey's  (HSD) test**
# 1. The difference in mean depth between cluster 0 and cluster 1 is statistically significant (p-value < 0.05)
# 2. The difference in mean depth between cluster 1 and cluster 2 is also statistically significant (p-value < 0.05)
# 3. The difference in mean depth between cluster 0 and cluster 2 is also statistically significant (p-value < 0.05)
#
# >>>>3.2.4.5 For rms
#
# >>>>**Null Hypothesis (H0):** There is no significant difference in the mean rms among clusters 0, 1, and 2.
#
# >>>>**Alternate Hypothesis (H1):** There is a significant difference in the mean rms among at least two of the clusters (0, 1, and 2).
#
# >>>>>p-value < 0.05, It is conclude that at least one of the mean rms among clusters 0,1 and 2 is significantly different.
#
# >>>>**Tukey's  (HSD) test**
# 1. The difference in mean rms between cluster 0 and cluster 1 is statistically significant (p-value < 0.05)
# 2. The difference in mean rms between cluster 1 and cluster 2 is also statistically significant (p-value < 0.05)
# 3. The difference in mean rms between cluster 0 and cluster 2 is also statistically significant (p-value < 0.05)
#
#
# >>>>3.2.4.6 For depthError
#
# >>>>**Null Hypothesis (H0):** There is no significant difference in the mean depthError among clusters 0, 1, and 2.
#
# >>>>**Alternate Hypothesis (H1):** There is a significant difference in the mean depthError among at least two of the clusters (0, 1, and 2).
#
# >>>>>p-value < 0.05, It is conclude that at least one of the mean depthError among clusters 0,1 and 2 is significantly different.
#
# >>>>**Tukey's  (HSD) test**
# 1. The difference in mean depthErrore between cluster 0 and cluster 1 is not  statistically significant (p-value > 0.05)
# 2. The difference in mean depthError between cluster 1 and cluster 2 is also statistically significant (p-value < 0.05)
# 3. The difference in mean depthError between cluster 0 and cluster 2 is also statistically significant (p-value < 0.05)

# %% [markdown]
# # 4. Results :
# >**K-Means:**
#
# >4.1. Appropriate Number of Segments | Clusters:
# >> Base Model (K-Means) : **3**
#
# >> BIRCH : **3**
#
# >4.3. Comapring Clustering Model Performance: Time & Memory Statistics : Base Model (K-Means) vs Comparison Models (BIRCH)
# >>>>
# ![image.png](data:image/png;base64,...)
# >>>> k-means is better algorithms in termas of sscore and dbscore
#
# >4.3. Cluster Analysis: Base Model (K-Means)
# >>4.3.1. Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant :
# >>>>>
# ![image.png](data:image/png;base64,...)
#
# >>4.3.2. Non-Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant (Base Models - K-Means) :
# >>>> ![image.png](data:image/png;base64,...)

# %% [markdown]
# #5. Managerial Insights
# >5.1. Appropriate Model : **K-Means**
#
# >5.2. Appropriate Number of Segments | Clusters :
# >>**Appropriate no. of segments are 3**
#
# >5.3. Identification of a Segment | Cluster
# >> **cluster 0 : Mild Quakes**
# >>> The seismic activity in this cluster is characterized by mild to moderate events, with the most frequent magnitude types being 'mb', 'mw', and 'mwc'. The seismic data predominantly originates from the 'us' network, both in terms of location source and magnitude source. Geographically, this cluster primarily represents seismic events occurring in the southern and western regions, with latitude ranging from -6.0 to -77.08 and longitude from -128.4 to -180.0. On average, the magnitude of earthquakes in this cluster is around 0.23, with a depth of approximately 0.93 kilometers. The Root Mean Square (RMS) values associated with these events are moderate, indicating relatively stable seismic activity within this cluster.
#
# >> **cluster 1 : Moderate Quakes**
# >>> This cluster exhibits diverse seismic types, predominantly 'mb', 'mw', and 'mwc', sourced from various networks and sources, with 'us' being the most frequent. Geographically, it represents moderate seismic activity centered in central and eastern regions, ranging from latitude -7.199 to 28.38 and longitude 75.9 to 180.0 degrees. The average magnitude within this cluster is approximately 0.66, with an average depth of around 1.08 kilometers. The RMS values indicate moderate seismic energy levels.
#
# >> **cluster 2 : Strong Quakes**
# >>> The cluster encompasses diverse seismic types, with 'mb', 'mw', and 'mwc' being the most frequent, sourced from various networks and sources, with 'us' prevailing. Geographically, it represents robust seismic activity concentrated in the northern and northeastern regions, spanning latitude -33.82 to 87.386 and longitude -56.84 to 81.29 degrees. The average magnitude within this cluster is approximately 0.60, with an average depth of around 0.60 kilometers. The RMS values suggest relatively low seismic energy levels.
# >>5.4. Segment | Cluster - (Heterogeneous) Identity | Nomenclature

# %%
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import scipy.stats as sps # For Probability & Inferential Statistics
import time
import psutil

# %%
# Display All Columns of Dataset
pd.set_option('display.max_columns', None)

# %%
from google.colab import files
import pandas as pd
import io

# Upload the file
uploaded = files.upload()

# Get the file name
file_name = next(iter(uploaded))

# Read the uploaded file into a DataFrame
df = pd.read_csv(io.BytesIO(uploaded[file_name]),index_col=0)
# Set the name of the index to "index" for df
df.index.name = 'index'
# Display the DataFrame
print(df)
# Out:
#      <input type="file" id="files-38c1dbbc-3431-4520-8804-c7e3043ff891" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38c1dbbc-3431-4520-8804-c7e3043ff891">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Data Bifurcation
df_cat = df[['magType','net','type','status','locationSource','magSource']] # Categorical Data [Nominal | Ordinal]
df_noncat=df[['time','latitude','longitude','depth','mag','nst','gap','dmin','rms','id','updated','place',
              'horizontalError','depthError','magError','magNst']]# Non-Categorical Data

# %% [markdown]
# ## Count and frequency statistics

# %%
for i in df_cat:
  count_stats = pd.concat([df_cat[i].value_counts(), df_cat[i].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
  print(i," : \n ",count_stats,"\n")
# Out:
# magType  :
#            index  count  percentage
# 0           mb  40503        40.0
# 1           mw  24318        24.0
# 2          mwc  17458        17.0
# 3          mww  11258        11.0
# 4           ms   3223         3.0
# 5          mwb   3062         3.0
# 6           ml    572         1.0
# 7          mwr    397         0.0
# 8           md     50         0.0
# 9           uk     41         0.0
# 10          fa     30         0.0
# 11          mh     23         0.0
# 12           m     21         0.0
# 13         mwp      9         0.0
# 14          Mi      6         0.0
# 15  ml(texnet)      4         0.0
# 16       ms_20      3         0.0
# 17          mc      2         0.0
# 18          lg      2         0.0
# 19         mlg      1         0.0
# 20       mb_lg      1         0.0
# 21          Md      1         0.0
# 22          Ml      1         0.0
# 23        mint      1         0.0
# 24          Mb      1         0.0
# 25          ma      1         0.0
#
# net  :
# ...

# %%
# Determine the number of rows and columns for the subplot grid
num_rows = 2  # Adjust as needed based on the number of categorical variables
num_cols = (len(df_cat.columns) + 1) // 2  # Divide the columns into two halves

# Create a subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12,8))

# Iterate over each categorical variable
for i, column in enumerate(df_cat.columns):
    # Calculate value counts for the current column
    value_counts = df_cat[column].value_counts()

    # Calculate the row and column index for the current subplot
    row_index = i // num_cols
    col_index = i % num_cols

    # Create a pie chart on the corresponding subplot
    ax = axes[row_index, col_index]
    ax.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
    ax.set_title(f"Pie Chart of {column}")
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Adjust layout and spacing
plt.tight_layout()
plt.show()

# %%
df_noncat. describe()
# Out:
#             latitude      longitude          depth            mag  \
# count  100989.000000  100989.000000  100704.000000  100989.000000
# mean        3.429606      41.036982      62.336160       5.451967
# std        30.043412     121.777260     108.522148       0.484050
# min       -77.080000    -180.000000      -4.000000       5.000000
# 25%       -17.827000     -72.050000      12.600000       5.100000
# 50%        -1.043000      99.800000      33.000000       5.300000
# 75%        29.331000     142.750000      51.375000       5.700000
# max        87.386000     180.000000     700.000000       9.500000
#
#                 nst           gap          dmin           rms  \
# count  30389.000000  40682.000000  20738.000000  72244.000000
# mean     155.090855     63.045442      4.246240      0.962483
# std      127.021673     38.485422      5.156825      0.375573
# min        0.000000      6.500000      0.000000     -1.000000
# ...

# %%
for i in ['latitude','longitude','depth','mag','nst','gap','dmin','rms',
              'horizontalError','depthError','magError','magNst']:
    # Calculate the standard deviation of each column
    std1 = round(np.std(df_noncat[i]), 2)
    print(f"Standard deviation of'{i}': {std1}")
# Out:
# Standard deviation of'latitude': 30.04
# Standard deviation of'longitude': 121.78
# Standard deviation of'depth': 108.52
# Standard deviation of'mag': 0.48
# Standard deviation of'nst': 127.02
# Standard deviation of'gap': 38.48
# Standard deviation of'dmin': 5.16
# Standard deviation of'rms': 0.38
# Standard deviation of'horizontalError': 4.4
# Standard deviation of'depthError': 10.81
# Standard deviation of'magError': 0.16
# Standard deviation of'magNst': 80.14

# %% [markdown]
# ## Test of Correlation

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sps

cols=['latitude',	'longitude','depth', 'mag',	'nst'	,'gap',	'dmin',	'rms','horizontalError','depthError','magError','magNst']
# Initialize an empty DataFrame to store p-values
p_values_df = pd.DataFrame(index=cols, columns=cols)

# Iterate over each pair of columns
for col1 in cols:
    for col2 in cols:
        # Skip if the columns are the same or if any of them is non-numeric
        if col1 == col2 or not (df_noncat[col1].dtype == 'float64' and df_noncat[col2].dtype == 'float64'):
            continue

        # Drop rows with NaN values in both columns
        filtered_df = df_noncat[[col1, col2]].dropna()

        # Perform Pearson correlation test
        _, p_value = sps.pearsonr(filtered_df[col1], filtered_df[col2])

        # Store the p-value in the DataFrame
        p_values_df.loc[col1, col2] = p_value

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(p_values_df.astype(float), annot=True, cmap='coolwarm', fmt=".3f", cbar_kws={'label': 'p-value'})
plt.title('Heatmap of Pearson Correlation P-values')
plt.xlabel('Variable')
plt.ylabel('Variable')
plt.show()

# %% [markdown]
# # Missing Data Statistics

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# index
# 0       9
# 2612    9
# 1217    9
# 9768    9
# 8319    9
# dtype: int64

# %%
# Dataset Used : df

df.info() # Dataframe Information (Provide Information on Missing Data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100989 entries, 0 to 100988
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             100989 non-null  object
#  1   latitude         100989 non-null  float64
#  2   longitude        100989 non-null  float64
#  3   depth            100704 non-null  float64
#  4   mag              100989 non-null  float64
#  5   magType          100989 non-null  object
#  6   nst              30389 non-null   float64
#  7   gap              40682 non-null   float64
#  8   dmin             20738 non-null   float64
#  9   rms              72244 non-null   float64
#  10  net              100989 non-null  object
#  11  id               100989 non-null  object
#  12  updated          100989 non-null  object
#  13  place            100100 non-null  object
#  14  type             100989 non-null  object
#  15  horizontalError  19363 non-null   float64
# ...

# %% [markdown]
# ##Missing Data Statistics: Categorical Variables or Features

# %%
variable_missing_data = df_cat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# magType           0
# net               0
# type              0
# status            0
# locationSource    0
# magSource         0
# dtype: int64

# %% [markdown]
# ## Missing Data Statistics: Non-Categorical Variables or Features

# %%
variable_missing_data = df_noncat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# time                   0
# latitude               0
# longitude              0
# depth                285
# mag                    0
# nst                70600
# gap                60307
# dmin               80251
# rms                28745
# id                     0
# updated                0
# place                889
# horizontalError    81626
# depthError         49713
# magError           66997
# magNst             59981
# dtype: int64

# %% [markdown]
# ## Removal of Records
#
# As nst, gap, dmin,horizontalError,magError,magNst have more than 50% records empty.
#
# place is a variable having name of place, which will not be considered for analysis

# %%
df_noncat_final=df_noncat.drop(['nst','gap','dmin','horizontalError','magError','magNst','place','id'],axis=1)
df_noncat_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100989 entries, 0 to 100988
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time        100989 non-null  object
#  1   latitude    100989 non-null  float64
#  2   longitude   100989 non-null  float64
#  3   depth       100704 non-null  float64
#  4   mag         100989 non-null  float64
#  5   rms         72244 non-null   float64
#  6   updated     100989 non-null  object
#  7   depthError  51276 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# ## Imputation of Missing Data using Descriptive Statistics: Mean | Median

# %%
# Dataset Used : df_noncat_final
df_noncat_missingvalues=df_noncat_final[['depth','rms','depthError']]
si_noncat = SimpleImputer(missing_values=np.nan, strategy='median')
si_noncat_fit = si_noncat.fit_transform(df_noncat_missingvalues)
# Preserve the index column in the new DataFrame
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat_missingvalues.columns, index=df_noncat_missingvalues.index)
df_noncat_mdi_si
# Out:
#          depth   rms  depthError
# index
# 0        33.00  0.97       4.930
# 1        33.00  0.97       4.930
# 2        33.00  0.97       4.930
# 3        33.00  0.97       4.930
# 4        33.00  0.97       4.930
# ...        ...   ...         ...
# 100984    8.67  0.83       2.937
# 100985   10.00  0.46       1.704
# 100986   90.00  0.84       1.935
# 100987  227.68  0.71       5.090
# 100988   43.94  0.76       6.316
#
# [100989 rows x 3 columns]

# %%
# Merge df_noncat_mdi_si1 and df_noncat_mdi_si2 on index
merged_df_noncat = pd.merge(df_noncat_final[['time', 'latitude', 'longitude','mag','updated']], df_noncat_mdi_si, left_index=True, right_index=True)
merged_df_noncat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100989 entries, 0 to 100988
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time        100989 non-null  object
#  1   latitude    100989 non-null  float64
#  2   longitude   100989 non-null  float64
#  3   mag         100989 non-null  float64
#  4   updated     100989 non-null  object
#  5   depth       100989 non-null  float64
#  6   rms         100989 non-null  float64
#  7   depthError  100989 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.0+ MB

# %% [markdown]
# ## Missing Data Exclusion [MCAR | MAR (> 50%)]

# %%
# Excluding Empty Records (If Any)
df_cat.dropna(axis=0, how='all', inplace=True) # Categorical Data Subset
merged_df_noncat.dropna(axis=0, how='all', inplace=True) # Non-Categorical Data Subset
# Out:
# <ipython-input-17-809b5d7d7681>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat.dropna(axis=0, how='all', inplace=True) # Categorical Data Subset

# %%
# Excluding Empty Variables (If Any)
df_cat.dropna(axis=1, how='all', inplace=True) # Categorical Data Subset
merged_df_noncat.dropna(axis=1, how='all', inplace=True) # Non-Categorical Data Subset
# Out:
# <ipython-input-18-d0549340a631>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat.dropna(axis=1, how='all', inplace=True) # Categorical Data Subset

# %% [markdown]
# ## 3.1.2. Numerical Encoding of Categorical Variables or Features (Encoding Schema - Alphanumeric Order)

# %%
# Dataset Used : df_cat_mdt
df_cat_mdt_code = df_cat.copy()

# %%
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=df_cat_mdt_code.columns); df_cat_code_oe
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#        magType_x  net_x      type_x  status_x locationSource_x magSource_x  \
# index
# 0             mw  ushis  earthquake  reviewed            ushis          pt
# 1             ms  ushis  earthquake  reviewed            ushis         ell
# 2             fa  ushis  earthquake  reviewed            ushis         sjg
# 3             ms  ushis  earthquake  reviewed            ushis         abe
# 4             ms  ushis  earthquake  reviewed            ushis         abe
# ...          ...    ...         ...       ...              ...         ...
# 100984       mww     us  earthquake  reviewed               us          us
# 100985       mww     us  earthquake  reviewed               us          us
# 100986       mww     us  earthquake  reviewed               us          us
# 100987       mww     us  earthquake  reviewed               us          us
# 100988       mww     us  earthquake  reviewed               us          us
#
# ...

# %%
# Assuming merged_df_noncat is your DataFrame containing the specified columns
import matplotlib.pyplot as plt
import seaborn as sns

# Columns to include in the box plot
columns = ['latitude', 'longitude', 'mag','depth', 'rms',
       'depthError']

# Create box plots for each column
plt.figure(figsize=(8, 4))
sns.set(style="whitegrid")

for column in columns:
    plt.figure(figsize=(4,2))
    sns.boxplot(data=merged_df_noncat[column], orient="h")
    plt.title(f"Box Plot of {column}")
    plt.xlabel("Value")
    plt.show()

# %%
df_noncat_mdt=merged_df_noncat[['mag','depth', 'rms','depthError']].copy()
#other_columns=df_noncat_final.loc[:, ~df_noncat_final.columns.isin(df_noncat_mdt.columns)]

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdt)
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mn'); df_noncat_minmax_norm
df_noncat_mdt_mmn = pd.merge(merged_df_noncat, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#                             time  latitude  longitude   mag  \
# index
# 0       1900-10-09T12:25:00.000Z   57.0900    -153.48  7.86
# 1       1901-03-03T07:45:00.000Z   36.0000    -120.50  6.40
# 2       1901-07-26T22:20:00.000Z   40.8000    -115.70  5.00
# 3       1901-12-30T22:34:00.000Z   52.0000    -160.00  7.00
# 4       1902-01-01T05:20:30.000Z   52.3800    -167.45  7.00
# ...                          ...       ...        ...   ...
# 100984  2024-01-27T16:13:56.152Z  -17.7720    -172.81  5.40
# 100985  2024-01-27T09:33:17.650Z  -11.6262     113.39  5.40
# 100986  2024-01-27T05:52:48.423Z   14.0652     -90.62  6.10
# 100987  2024-01-27T02:15:26.991Z   -5.4377     147.02  5.40
# 100988  2024-01-27T01:36:45.009Z   11.7896     142.24  5.10
#
#                          updated   depth   rms  depthError    mag_mn  \
# index
# 0       2022-05-09T14:44:17.838Z   33.00  0.97       4.930  0.635556
# 1       2018-06-04T20:43:44.000Z   33.00  0.97       4.930  0.311111
# ...

# %% [markdown]
# # Pre-Processed Dataset

# %% [markdown]
# # Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd
# Out:
#        magType_x  net_x      type_x  status_x locationSource_x magSource_x  \
# index
# 0             mw  ushis  earthquake  reviewed            ushis          pt
# 1             ms  ushis  earthquake  reviewed            ushis         ell
# 2             fa  ushis  earthquake  reviewed            ushis         sjg
# 3             ms  ushis  earthquake  reviewed            ushis         abe
# 4             ms  ushis  earthquake  reviewed            ushis         abe
# ...          ...    ...         ...       ...              ...         ...
# 100984       mww     us  earthquake  reviewed               us          us
# 100985       mww     us  earthquake  reviewed               us          us
# 100986       mww     us  earthquake  reviewed               us          us
# 100987       mww     us  earthquake  reviewed               us          us
# 100988       mww     us  earthquake  reviewed               us          us
#
# ...

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd
# Out:
#                             time  latitude  longitude   mag  \
# index
# 0       1900-10-09T12:25:00.000Z   57.0900    -153.48  7.86
# 1       1901-03-03T07:45:00.000Z   36.0000    -120.50  6.40
# 2       1901-07-26T22:20:00.000Z   40.8000    -115.70  5.00
# 3       1901-12-30T22:34:00.000Z   52.0000    -160.00  7.00
# 4       1902-01-01T05:20:30.000Z   52.3800    -167.45  7.00
# ...                          ...       ...        ...   ...
# 100984  2024-01-27T16:13:56.152Z  -17.7720    -172.81  5.40
# 100985  2024-01-27T09:33:17.650Z  -11.6262     113.39  5.40
# 100986  2024-01-27T05:52:48.423Z   14.0652     -90.62  6.10
# 100987  2024-01-27T02:15:26.991Z   -5.4377     147.02  5.40
# 100988  2024-01-27T01:36:45.009Z   11.7896     142.24  5.10
#
#                          updated   depth   rms  depthError    mag_mn  \
# index
# 0       2022-05-09T14:44:17.838Z   33.00  0.97       4.930  0.635556
# 1       2018-06-04T20:43:44.000Z   33.00  0.97       4.930  0.311111
# ...

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
# Out:
#        magType_x  net_x      type_x  status_x locationSource_x magSource_x  \
# index
# 0             mw  ushis  earthquake  reviewed            ushis          pt
# 1             ms  ushis  earthquake  reviewed            ushis         ell
# 2             fa  ushis  earthquake  reviewed            ushis         sjg
# 3             ms  ushis  earthquake  reviewed            ushis         abe
# 4             ms  ushis  earthquake  reviewed            ushis         abe
# ...          ...    ...         ...       ...              ...         ...
# 100984       mww     us  earthquake  reviewed               us          us
# 100985       mww     us  earthquake  reviewed               us          us
# 100986       mww     us  earthquake  reviewed               us          us
# 100987       mww     us  earthquake  reviewed               us          us
# 100988       mww     us  earthquake  reviewed               us          us
#
# ...

# %% [markdown]
# # Data Bifurcation [Training & Testing Datasets]

# %%
# Dataset Used : df_ppd

train_df, test_df = train_test_split(df_ppd, test_size=0.25, random_state=1234)
#train_df # Training Dataset
#test_df # Testing Dataset

# %% [markdown]
# ## creating a subset for applying clustering
#
# we have choose these columns for clustering : 'magType_y','magSource_y','latitude','longitude','mag_mn', 'depth_mn','rms_mn','depthError_mn':
#
#        1. Variability in Event Types
#        2. identification of seismic hotspots and regions prone,Magnitude Patterns
#        3. Depth Insights
#        4. Insights into the distribution of seismic monitoring infrastructure and its impact on earthquake detection.

# %%
df_ppd.columns
# Out:
# Index(['magType_x', 'net_x', 'type_x', 'status_x', 'locationSource_x',
#        'magSource_x', 'magType_y', 'net_y', 'type_y', 'status_y',
#        'locationSource_y', 'magSource_y', 'time', 'latitude', 'longitude',
#        'mag', 'updated', 'depth', 'rms', 'depthError', 'mag_mn', 'depth_mn',
#        'rms_mn', 'depthError_mn'],
#       dtype='object')

# %%
# creating Subset for earthqake having columns required for clustering
earthquake_subset =df_ppd[['magType_y', 'net_y', 'type_y', 'status_y',
                           'locationSource_y', 'magSource_y','latitude',
                           'longitude','mag_mn', 'depth_mn',
                           'rms_mn','depthError_mn']];

# %% [markdown]
# #### Plotting Depth vs Magnitude Scatter Plot

# %%
# Plottting
plt.scatter(x='mag_mn', y='depth_mn', data=earthquake_subset, c='depth_mn', cmap='Spectral')
plt.xlabel('Magnitude')
plt.ylabel('Depth')
plt.title('Depth vs Magnitude Scatter Plot')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# #### Plotting magnitude and depth with respect to latitude and longitude

# %%
import matplotlib.pyplot as plt

# Define the data
latitude = earthquake_subset['latitude']
longitude = earthquake_subset['longitude']
depth = earthquake_subset['depth_mn']
magnitude = earthquake_subset['mag_mn']

# Plotting on a map
plt.figure(figsize=(10, 8))
plt.scatter(longitude, latitude, c=depth, s=magnitude, cmap='viridis', alpha=0.5)
plt.colorbar(label='depth')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Earthquake Distribution with Depth and Magnitude')
plt.grid(True)
plt.show()

# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ## Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia

# %%
'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(earthquake_subset)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
def memory_usage():
    """
    Function to get memory usage.
    """
    process = psutil.Process()
    mem = process.memory_info().rss
    return mem / (1024 * 1024)  # Convert to MB

# %% [markdown]
# ## Using K- Means

# %%
#start time
start = time.time()
# Measure memory usage
memory_before = memory_usage()

# %%
km_2cluster = kmclus(n_clusters=2, init='random', random_state=222)
km_2cluster_model = km_2cluster.fit_predict(earthquake_subset); km_2cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 1, 1], dtype=int32)

# %%
km_3cluster = kmclus(n_clusters=3, init='random', random_state=333)
km_3cluster_model = km_3cluster.fit_predict(earthquake_subset); print(km_3cluster_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [0 0 0 ... 0 1 1]

# %%
km_4cluster = kmclus(n_clusters=4, init='random', random_state=444)
km_4cluster_model = km_4cluster.fit_predict(earthquake_subset); km_3cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 1, 1], dtype=int32)

# %%
km_5cluster = kmclus(n_clusters=5, init='random', random_state=555)
km_5cluster_model = km_5cluster.fit_predict(earthquake_subset); km_3cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 1, 1], dtype=int32)

# %% [markdown]
# ## K-Means Clustering Model Evaluation

# %%
sscore_km_2cluster = sscore(earthquake_subset, km_2cluster_model);
dbscore_km_2cluster = dbscore(earthquake_subset, km_2cluster_model);
print("sscore for k=2 : ",sscore_km_2cluster)
print("dbscore for k=2 : ",dbscore_km_2cluster)
# Out:
# sscore for k=2 :  0.6571654094290492
# dbscore for k=2 :  0.5104568611314296

# %%
sscore_km_3cluster = sscore(earthquake_subset, km_3cluster_model)
dbscore_km_3cluster = dbscore(earthquake_subset, km_3cluster_model)
print("sscore for k=3 : ",sscore_km_3cluster)
print("dbscore for k=3 : ",dbscore_km_3cluster)
# Out:
# sscore for k=3 :  0.4837461736594839
# dbscore for k=3 :  0.8705279868593099

# %%
sscore_km_4cluster = sscore(earthquake_subset, km_4cluster_model)
dbscore_km_4cluster = dbscore(earthquake_subset, km_4cluster_model)
print("sscore for k=4 : ",sscore_km_4cluster)
print("dbscore for k=4 : ",dbscore_km_4cluster)
# Out:
# sscore for k=4 :  0.4026628321099051
# dbscore for k=4 :  1.0211128934844567

# %%
sscore_km_5cluster = sscore(earthquake_subset, km_5cluster_model)
dbscore_km_5cluster = dbscore(earthquake_subset, km_5cluster_model)
print("sscore for k=5 : ",sscore_km_5cluster)
print("dbscore for k=5 : ",dbscore_km_5cluster)
# Out:
# sscore for k=5 :  0.36639858766082456
# dbscore for k=5 :  1.124739469846887

# %%
import matplotlib.pyplot as plt

# Define cluster names and scores
cluster_names = ['2 clusters', '3 clusters', '4 clusters', '5 clusters']
sscore_values = [sscore_km_2cluster, sscore_km_3cluster, sscore_km_4cluster, sscore_km_5cluster]
dbscore_values = [dbscore_km_2cluster, dbscore_km_3cluster, dbscore_km_4cluster, dbscore_km_5cluster]

# Plotting both scores on the same graph
plt.figure(figsize=(6, 2))

# Plotting the Silhouette Score
plt.plot(cluster_names, sscore_values, marker='o', color='blue', label='Silhouette Score')

# Plotting the Davies-Bouldin Score
plt.plot(cluster_names, dbscore_values, marker='o', color='red', label='Davies-Bouldin Score')

# Adding title and labels
plt.title('Cluster Evaluation Scores for Different Numbers of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # 4. Create a KMeans Cluster Member Dataframe
#
# #### Cluster Model Used : km_3cluster_model (Based on sscore and dbscore)

# %%
earthquake_subset_kmcluster = earthquake_subset.copy()
earthquake_subset_kmcluster['cluster_number'] = km_3cluster_model
earthquake_subset_kmcluster.sort_values('cluster_number', inplace=True);
print(earthquake_subset_kmcluster)
# Out:
#        magType_y  net_y  type_y  status_y  locationSource_y  magSource_y  \
# index
# 0           19.0   18.0     0.0       1.0              83.0         64.0
# 74457       21.0   17.0     0.0       1.0              78.0         27.0
# 74456       21.0   17.0     0.0       1.0              78.0         27.0
# 74455       20.0   17.0     0.0       1.0              78.0         80.0
# 31245        8.0   17.0     0.0       1.0              78.0         80.0
# ...          ...    ...     ...       ...               ...          ...
# 79865       23.0   17.0     0.0       1.0              78.0         80.0
# 79861        8.0   17.0     0.0       1.0              78.0         80.0
# 79856       20.0   17.0     0.0       1.0              78.0         80.0
# 79853       24.0   17.0     0.0       1.0              78.0         80.0
# 26609       17.0   17.0     0.0       1.0              78.0         80.0
#
#        latitude  longitude    mag_mn  depth_mn    rms_mn  depthError_mn  \
# index
# ...

# %%
# end time
end = time.time()
# Memory afterward
memory_after = memory_usage()

# total time taken
print(f"Runtime of the program is {end - start}")
print("Memory usage difference:", memory_after - memory_before, "MB")
# Out:
# Runtime of the program is 601.8391733169556
# Memory usage difference: 0.8515625 MB

# %% [markdown]
# #5. Plotting the cluster

# %%
from matplotlib.colors import ListedColormap  # Import ListedColormap
# Create a custom colormap with pink, sky blue, and yellow
custom_cmap = ListedColormap(['pink', 'skyblue','yellow'])

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define cluster labels
cluster_labels = list(earthquake_subset_kmcluster['cluster_number'].unique())

# Plot the clustered data in 3D
scatter_plot = ax.scatter(xs=earthquake_subset_kmcluster['depth_mn'],
                          ys=earthquake_subset_kmcluster['mag_mn'],
                          zs=earthquake_subset_kmcluster['cluster_number'],  # Use cluster_number for the z-axis
                          c=earthquake_subset_kmcluster['cluster_number'],
                          cmap=custom_cmap)  # Use custom colormap

# Set labels and title
ax.set_xlabel('Depth')
ax.set_ylabel('Magnitude')
ax.set_zlabel('Cluster Number')
ax.set_title('Depth vs Magnitude Scatter Plot : K-Means Clusters')

# Add legend
plt.legend(handles=scatter_plot.legend_elements()[0], labels=cluster_labels)

# Show grid
ax.grid()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define data
latitude = earthquake_subset_kmcluster['latitude']
longitude = earthquake_subset_kmcluster['longitude']
magnitude = earthquake_subset_kmcluster['mag_mn']
cluster_number = earthquake_subset_kmcluster['cluster_number']

# Create a new figure
plt.figure(figsize=(8, 6))

# Plot each cluster separately on the map
for cluster in range(cluster_number.max() + 1):
    cluster_data = earthquake_subset_kmcluster[earthquake_subset_kmcluster['cluster_number'] == cluster]
    plt.scatter(cluster_data['longitude'], cluster_data['latitude'], s=cluster_data['mag_mn']*10, alpha=0.5, label=f'Cluster {cluster}')

# Add colorbar and labels
plt.colorbar(label='Magnitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Earthquake Clusters Distribution')
plt.legend()
plt.grid(True)

# Show the map
plt.show()

# %% [markdown]
# ## Splitting the dataframe based on cluster.

# %%
earthquake_cluster0= earthquake_subset_kmcluster[earthquake_subset_kmcluster['cluster_number'] == 0]
earthquake_cluster1= earthquake_subset_kmcluster[earthquake_subset_kmcluster['cluster_number'] == 1]
earthquake_cluster2= earthquake_subset_kmcluster[earthquake_subset_kmcluster['cluster_number'] == 2]

# %%
earthquake_cluster1.describe()
# Out:
#           magType_y         net_y        type_y      status_y  \
# count  55868.000000  55868.000000  55868.000000  55868.000000
# mean      14.945335     15.348804      0.009433      0.999553
# std        6.390039      4.126740      0.167746      0.021149
# min        0.000000      0.000000      0.000000      0.000000
# 25%        8.000000     17.000000      0.000000      1.000000
# 50%       19.000000     17.000000      0.000000      1.000000
# 75%       21.000000     17.000000      0.000000      1.000000
# max       25.000000     18.000000      3.000000      1.000000
#
#        locationSource_y   magSource_y      latitude    longitude  \
# count      55868.000000  55868.000000  55868.000000  55868.00000
# mean          71.487649     62.444942      7.882157    137.49588
# std           16.303709     22.331492     24.913782     23.56644
# min            2.000000      0.000000    -76.313000     75.90000
# 25%           78.000000     38.000000     -7.199000    123.96000
# ...

# %%
earthquake_cluster0.describe()
# Out:
#           magType_y         net_y        type_y      status_y  \
# count  29725.000000  29725.000000  29725.000000  29725.000000
# mean      15.933154     14.988629      0.028057      0.997813
# std        6.232045      4.652969      0.317830      0.046712
# min        1.000000      0.000000      0.000000      0.000000
# 25%        8.000000     17.000000      0.000000      1.000000
# 50%       19.000000     17.000000      0.000000      1.000000
# 75%       21.000000     17.000000      0.000000      1.000000
# max       25.000000     20.000000      5.000000      1.000000
#
#        locationSource_y   magSource_y      latitude     longitude  \
# count      29725.000000  29725.000000  29725.000000  29725.000000
# mean          68.846022     59.220454     -6.028374   -128.398765
# std           19.802957     23.879496     30.486052     45.428668
# min            0.000000      0.000000    -77.080000   -180.000000
# 25%           78.000000     34.000000    -27.791000   -175.840000
# ...

# %%
earthquake_cluster2.describe()
# Out:
#           magType_y         net_y        type_y      status_y  \
# count  15396.000000  15396.000000  15396.000000  15396.000000
# mean      16.235840     14.198168      0.012796      0.999091
# std        6.016059      5.032318      0.195845      0.030142
# min        6.000000      3.000000      0.000000      0.000000
# 25%        8.000000     17.000000      0.000000      1.000000
# 50%       19.000000     17.000000      0.000000      1.000000
# 75%       21.000000     17.000000      0.000000      1.000000
# max       24.000000     17.000000      4.000000      1.000000
#
#        locationSource_y   magSource_y      latitude     longitude  \
# count      15396.000000  15396.000000  15396.000000  15396.000000
# mean          66.329241     58.083593      5.532969     18.142193
# std           20.321332     22.644427     40.310425     39.490175
# min            6.000000      8.000000    -63.938000    -56.840000
# 25%           68.000000     38.000000    -33.823900    -25.082500
# ...

# %% [markdown]
# #### 3.2.3.1 Cluster Analysis: Base Model (K-Means)

# %% [markdown]
# ######3.2.3.1.1 Cluster Analysis with Categorical Variables or Features: Chi-Square Test of Independence

# %%
from scipy.stats import chi2_contingency

# Extracting categorical variables
cat_variables = ['magType_y', 'net_y', 'type_y', 'status_y', 'locationSource_y','magSource_y']

# Perform Chi-square test for each categorical variable
chi2_results_cat = {}
for column in cat_variables:
    contingency_table = pd.crosstab(earthquake_subset_kmcluster[column], km_3cluster_model)
    chi2, p_value, _, _ = chi2_contingency(contingency_table)
    chi2_results_cat[column] = {'Chi-square': chi2, 'P-value': p_value}

# Print Chi-square test results for categorical variables
for column, result in chi2_results_cat.items():
    print(f"for: {column}")
    print(f"Chi-square: {result['Chi-square']}")
    print(f"P-value: {result['P-value']}")
    print("________")
# Out:
# for: magType_y
# Chi-square: 109.39445297372274
# P-value: 2.5394487406363326e-06
# ________
# for: net_y
# Chi-square: 111.64806534591548
# P-value: 1.0852210698170757e-08
# ________
# for: type_y
# Chi-square: 6.201628524277111
# P-value: 0.7980482952859123
# ________
# for: status_y
# Chi-square: 1.3841279115495686
# P-value: 0.5005419058425121
# ________
# for: locationSource_y
# Chi-square: 284.2308571552886
# P-value: 2.6040024952918196e-07
# ________
# for: magSource_y
# Chi-square: 291.59789206549755
# P-value: 2.724334525454367e-07
# ________

# %% [markdown]
# #ANOVA

# %%
# ANOVA Using Scipy
anova_lat = sps.f_oneway(earthquake_cluster0.latitude,earthquake_cluster1.latitude,earthquake_cluster2.latitude) # ANOVA
anova_lat
# Out:
# F_onewayResult(statistic=2217.4884309902886, pvalue=0.0)

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_lat = sps.tukey_hsd(earthquake_cluster0.latitude,earthquake_cluster1.latitude,earthquake_cluster2.latitude)
print(mean_pairwise_lat)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)    -13.911     0.000   -14.405   -13.416
#  (0 - 2)    -11.561     0.000   -12.246   -10.877
#  (1 - 0)     13.911     0.000    13.416    14.405
#  (1 - 2)      2.349     0.000     1.722     2.976
#  (2 - 0)     11.561     0.000    10.877    12.246
#  (2 - 1)     -2.349     0.000    -2.976    -1.722

# %%
# ANOVA Using Scipy
anova_lon = sps.f_oneway(earthquake_cluster0.longitude,earthquake_cluster1.longitude,earthquake_cluster2.longitude) # ANOVA
anova_lon
# Out:
# F_onewayResult(statistic=599277.4359360596, pvalue=0.0)

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_lon = sps.tukey_hsd(earthquake_cluster0.longitude,earthquake_cluster1.longitude,earthquake_cluster2.longitude)
print(mean_pairwise_lon)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)   -265.895     0.000  -266.466  -265.323
#  (0 - 2)   -146.541     0.000  -147.331  -145.751
#  (1 - 0)    265.895     0.000   265.323   266.466
#  (1 - 2)    119.354     0.000   118.629   120.078
#  (2 - 0)    146.541     0.000   145.751   147.331
#  (2 - 1)   -119.354     0.000  -120.078  -118.629

# %%
# ANOVA Using Scipy
anova_magnitude = sps.f_oneway(earthquake_cluster0.mag_mn,earthquake_cluster1.mag_mn,earthquake_cluster2.mag_mn) # ANOVA
anova_magnitude
# Out:
# F_onewayResult(statistic=55.422034317979744, pvalue=8.784483128980227e-25)

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_lon = sps.tukey_hsd(earthquake_cluster0.mag_mn,earthquake_cluster1.mag_mn,earthquake_cluster2.mag_mn)
print(mean_pairwise_lon)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)      0.003     0.000     0.002     0.005
#  (0 - 2)      0.011     0.000     0.009     0.014
#  (1 - 0)     -0.003     0.000    -0.005    -0.002
#  (1 - 2)      0.008     0.000     0.005     0.010
#  (2 - 0)     -0.011     0.000    -0.014    -0.009
#  (2 - 1)     -0.008     0.000    -0.010    -0.005

# %%
# ANOVA Using Scipy
anova_depth = sps.f_oneway(earthquake_cluster0.depth_mn,earthquake_cluster1.depth_mn,earthquake_cluster2.depth_mn) # ANOVA
anova_depth
# Out:
# F_onewayResult(statistic=1382.791658045423, pvalue=0.0)

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_depth = sps.tukey_hsd(earthquake_cluster0.depth_mn,earthquake_cluster1.depth_mn,earthquake_cluster2.depth_mn)
print(mean_pairwise_depth)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)      0.027     0.000     0.024     0.030
#  (0 - 2)      0.079     0.000     0.076     0.083
#  (1 - 0)     -0.027     0.000    -0.030    -0.024
#  (1 - 2)      0.052     0.000     0.049     0.056
#  (2 - 0)     -0.079     0.000    -0.083    -0.076
#  (2 - 1)     -0.052     0.000    -0.056    -0.049

# %%
# ANOVA Using Scipy
anova_rms = sps.f_oneway(earthquake_cluster0.rms_mn,earthquake_cluster1.rms_mn,earthquake_cluster2.rms_mn) # ANOVA
anova_rms
# Out:
# F_onewayResult(statistic=60.030879288903925, pvalue=8.798446498623824e-27)

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_rms = sps.tukey_hsd(earthquake_cluster0.rms_mn,earthquake_cluster1.rms_mn,earthquake_cluster2.rms_mn)
print(mean_pairwise_rms)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)      0.000     0.000     0.000     0.000
#  (0 - 2)      0.000     0.000     0.000     0.001
#  (1 - 0)     -0.000     0.000    -0.000    -0.000
#  (1 - 2)      0.000     0.000     0.000     0.000
#  (2 - 0)     -0.000     0.000    -0.001    -0.000
#  (2 - 1)     -0.000     0.000    -0.000    -0.000

# %%
# ANOVA Using Scipy
anova_depthError = sps.f_oneway(earthquake_cluster0.depthError_mn,earthquake_cluster1.depthError_mn,earthquake_cluster2.depthError_mn) # ANOVA
anova_depthError
# Out:
# F_onewayResult(statistic=19.058368083975413, pvalue=5.304171561979676e-09)

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_depthError = sps.tukey_hsd(earthquake_cluster0.depthError_mn,earthquake_cluster1.depthError_mn,earthquake_cluster2.depthError_mn)
print(mean_pairwise_depthError)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)     -0.000     0.000    -0.000    -0.000
#  (0 - 2)     -0.000     0.000    -0.000    -0.000
#  (1 - 0)      0.000     0.000     0.000     0.000
#  (1 - 2)      0.000     0.820    -0.000     0.000
#  (2 - 0)      0.000     0.000     0.000     0.000
#  (2 - 1)     -0.000     0.820    -0.000     0.000

# %% [markdown]
# # Using BIRCH

# %%
#start time
start_b = time.time()
# Measure memory usage
memory_before_b = memory_usage()

# %%
from sklearn.cluster import Birch

# %%
model = Birch(branching_factor = 50, n_clusters = 2, threshold = 1.5)
# Fit the model to the data
pred=model.fit(earthquake_subset)
# Get cluster labels
cluster_labels2 = pred.labels_
# Get cluster labels
cluster_labels2
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
# Compute silhouette score
ss2= sscore(earthquake_subset,cluster_labels2)
print("Silhouette Score:", ss2)
# Compute Davies-Bouldin score
db2 = dbscore(earthquake_subset,cluster_labels2)
print("Davies-Bouldin Score:", db2)
# Out:
# Silhouette Score: 0.6377916178043417
# Davies-Bouldin Score: 0.5358308925788589

# %%
model = Birch(branching_factor = 50, n_clusters = 3, threshold = 1.5)
# Fit the model to the data
pred=model.fit(earthquake_subset)
# Get cluster labels
cluster_labels3 = pred.labels_
# Get cluster labels
cluster_labels3
# Out:
# array([1, 1, 1, ..., 1, 0, 0])

# %%
# Compute silhouette score
ss3 = sscore(earthquake_subset,cluster_labels3)
print("Silhouette Score:", ss3)
# Compute Davies-Bouldin score
db3 = dbscore(earthquake_subset,cluster_labels3)
print("Davies-Bouldin Score:", db3)
# Out:
# Silhouette Score: 0.4812678289604788
# Davies-Bouldin Score: 0.9295387194690976

# %%
model = Birch(branching_factor = 50, n_clusters = 4, threshold = 1.5)
# Fit the model to the data
pred=model.fit(earthquake_subset)
# Get cluster labels
cluster_labels4 = pred.labels_
# Get cluster labels
cluster_labels4
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
# Compute silhouette score
ss3 = sscore(earthquake_subset,cluster_labels4)
print("Silhouette Score:", ss3)
# Compute Davies-Bouldin score
db3 = dbscore(earthquake_subset,cluster_labels4)
print("Davies-Bouldin Score:", db3)
# Out:
# Silhouette Score: 0.31347066491550424
# Davies-Bouldin Score: 1.1801994568758292

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import Birch
model = Birch(branching_factor = 50, n_clusters = 5, threshold = 1.5)
# Fit the model to the data
pred=model.fit(earthquake_subset)
# Get cluster labels
cluster_labels5 = pred.labels_
# Get cluster labels
cluster_labels5
# Out:
# array([4, 4, 4, ..., 2, 1, 1])

# %%
# Compute silhouette score
ss5 = sscore(earthquake_subset,cluster_labels5)
print("Silhouette Score:",ss5)
db5 = dbscore(earthquake_subset,cluster_labels5)
print("Davies-Bouldin Score:", db5)
# Out:
# Silhouette Score: 0.2715342383955696
# Davies-Bouldin Score: 1.31344304993264

# %%
earthquake_subset_birch = earthquake_subset.copy()
earthquake_subset_birch ['cluster_number'] = cluster_labels3
earthquake_subset_birch .sort_values('cluster_number', inplace=True);
print(earthquake_subset_birch )
# Out:
#        magType_y  net_y  type_y  status_y  locationSource_y  magSource_y  \
# index
# 50494       19.0   17.0     0.0       1.0              78.0         34.0
# 58448       21.0   17.0     0.0       1.0              78.0         34.0
# 58447       21.0   17.0     0.0       1.0              78.0         34.0
# 58446       21.0   17.0     0.0       1.0              78.0         34.0
# 58445       21.0   17.0     0.0       1.0              78.0         34.0
# ...          ...    ...     ...       ...               ...          ...
# 7434        19.0    5.0     0.0       1.0              31.0         38.0
# 88162        8.0   17.0     0.0       1.0              78.0         80.0
# 88163        8.0   17.0     0.0       1.0              78.0         80.0
# 88132       24.0   17.0     0.0       1.0              78.0         80.0
# 38525       19.0   17.0     0.0       1.0              78.0         34.0
#
#        latitude  longitude    mag_mn  depth_mn    rms_mn  depthError_mn  \
# index
# ...

# %%
# end time
end_b = time.time()
# Memory afterward
memory_after_b = memory_usage()

# total time taken
print(f"Runtime of the program is {end_b - start_b}")
print("Memory usage difference:", memory_after_b - memory_before_b, "MB")
# Out:
# Runtime of the program is 405.3320965766907
# Memory usage difference: 55.109375 MB

# %%
from matplotlib.colors import ListedColormap  # Import ListedColormap
# Create a custom colormap with pink, sky blue, and yellow
custom_cmap = ListedColormap(['pink', 'skyblue','yellow'])

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define cluster labels
cluster_labels = list(earthquake_subset_birch['cluster_number'].unique())

# Plot the clustered data in 3D
scatter_plot = ax.scatter(xs=earthquake_subset_birch['depth_mn'],
                          ys=earthquake_subset_birch['mag_mn'],
                          zs=earthquake_subset_birch['cluster_number'],  # Use cluster_number for the z-axis
                          c=earthquake_subset_birch['cluster_number'],
                          cmap=custom_cmap)  # Use custom colormap

# Set labels and title
ax.set_xlabel('Depth')
ax.set_ylabel('Magnitude')
ax.set_zlabel('Cluster Number')
ax.set_title('Depth vs Magnitude Scatter Plot : K-Means Clusters')

# Add legend
plt.legend(handles=scatter_plot.legend_elements()[0], labels=cluster_labels)

# Show grid
ax.grid()

# Show plot
plt.show()
